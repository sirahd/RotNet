# %%
# %matplotlib inline
# %autoreload 2

from __future__ import print_function

import os
import sys
import matplotlib.pyplot as plt
from keras.applications.imagenet_utils import preprocess_input
from keras.models import load_model
import tensorflow as tf

tf.debugging.disable_traceback_filtering()

sys.path.append('..')
from utils import display_examples, RotNetDataGenerator, angle_error, binarize_images
import glob

# %%
model_location = os.path.join('..', 'models', 'rotnet_mnist.hdf5')
model = load_model(model_location, custom_objects={'angle_error': angle_error})

# %%
filenames = glob.glob('/Users/samhorradarn/Pictures/archive/1/resized/*.jpg')

dataset = RotNetDataGenerator(
    filenames,
    input_shape=(200, 300, 3),
    batch_size=64,
    preprocess_func=preprocess_input,
    # crop_center=True,
    # crop_largest_rect=True,
)

out = model.evaluate_generator(dataset, steps=len(filenames)/64)
# Out:
# /var/folders/49/0f9phc990nx8hlxk_rkp3_8r0000gn/T/ipykernel_62285/2798305562.py:12: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   out = model.evaluate_generator(dataset, steps=len(filenames)/64)
# float32 float32
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 12
#       1 filenames = glob.glob('/Users/samhorradarn/Pictures/archive/1/resized/*.jpg')
#       3 dataset = RotNetDataGenerator(
#       4     filenames,
#       5     input_shape=(200, 300, 3),
#    (...)
#       9     # crop_largest_rect=True,
#      10 )
# ---> 12 out = model.evaluate_generator(dataset, steps=len(filenames)/64)
#
# ...
